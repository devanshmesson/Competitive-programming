# %% [markdown]
# <a href="https://colab.research.google.com/github/zeph0yr/Competitive-programming/blob/master/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import quandl
import datetime
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline
from pandas_datareader import DataReader
# For time stamps
from datetime import datetime
# For division
from __future__ import division
tech_list = ['AAPL','GOOGL','MSFT','AMZN']

# set up Start and End time for data grab
end = datetime.now()
start = datetime(end.year-1,end.month,end.day)

#For-loop for grabing google finance data and setting as a dataframe
# Set DataFrame as the Stock Ticker

for stock in tech_list:
    globals()[stock] = DataReader(stock,'yahoo',start,end)

AAPL.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2019-01-30  166.149994  160.229996  ...  61109800.0  162.803864
# 2019-01-31  169.000000  164.559998  ...  40739600.0  163.976242
# 2019-02-01  168.979996  165.929993  ...  32668100.0  164.055069
# 2019-02-04  171.660004  167.279999  ...  31495500.0  168.715042
# 2019-02-05  175.080002  172.350006  ...  36101600.0  171.601685
#
# [5 rows x 6 columns]

# %%
pylab.rcParams['figure.figsize'] =(15, 9)   # Change the size of plots 
AAPL["Adj Close"].plot(grid = True) # Plot the adjusted closing price of AAPL

# %%
from matplotlib.dates import DateFormatter, WeekdayLocator,DayLocator, MONDAY
from mpl_finance import candlestick_ohlc
#!pip install MyCandleStick
import plotly.graph_objects as go
from datetime import datetime

fig = go.Figure(data=[go.Candlestick(
                open=AAPL['High'],
                high=AAPL['Low'],
                low=AAPL['Open'],
                close=AAPL['Close'])])
#fig.update_layout(xaxis_rangeslider_visible=False)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e325649-3f34-4b2e-b01c-ce012123cbaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e325649-3f34-4b2e-b01c-ce012123cbaa")) {
#                     Plotly.newPlot(
#                         '7e325649-3f34-4b2e-b01c-ce012123cbaa',
# ...

# %%
AAPL["20d"] = np.round(AAPL["Adj Close"].rolling(window = 20, center = False).mean(), 2)
#pandas_candlestick_ohlc()
# Out:
#   File "<ipython-input-138-d4ae6d2df218>", line 3
#     fig = go.Figure(data=[go.Candlestick(int(AAPL['Date'].split('-')[2])])
#                                                                         ^
# SyntaxError: invalid syntax
